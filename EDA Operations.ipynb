# %%
import pandas as pd
df = pd.read_csv("student_exam_performance.csv")

# %%
df.head()
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# 2              60              High School              No
# 3              88                   Master             Yes
# 4              55              High School              No
#
#   Extracurricular_Activities  Sleep_Hours  Final_Exam_Score Pass_Fail
# 0                        Yes            7                72      Pass
# ...

# %%
df.shape
# Out:
# (10, 12)

# %%
df.tail()
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 5       S006  Female   18                    14                     88
# 6       S007    Male   17                    10                     80
# 7       S008  Female   16                    18                     93
# 8       S009    Male   18                     7                     72
# 9       S010  Female   17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 5              70                 Bachelor             Yes
# 6              65                 Bachelor             Yes
# 7              85                   Master             Yes
# 8              58              High School              No
# 9              78                 Bachelor             Yes
#
#   Extracurricular_Activities  Sleep_Hours  Final_Exam_Score Pass_Fail
# 5                        Yes            7                76      Pass
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Study_Hours_Per_Week',
#        'Attendance_Percentage', 'Previous_Score', 'Parental_Education_Level',
#        'Internet_Access', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Final_Exam_Score', 'Pass_Fail'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Student_ID                      str
# Gender                          str
# Age                           int64
# Study_Hours_Per_Week          int64
# Attendance_Percentage         int64
# Previous_Score                int64
# Parental_Education_Level        str
# Internet_Access                 str
# Extracurricular_Activities      str
# Sleep_Hours                   int64
# Final_Exam_Score              int64
# Pass_Fail                       str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  10 non-null     str
#  1   Gender                      10 non-null     str
#  2   Age                         10 non-null     int64
#  3   Study_Hours_Per_Week        10 non-null     int64
#  4   Attendance_Percentage       10 non-null     int64
#  5   Previous_Score              10 non-null     int64
#  6   Parental_Education_Level    10 non-null     str
#  7   Internet_Access             10 non-null     str
#  8   Extracurricular_Activities  10 non-null     str
#  9   Sleep_Hours                 10 non-null     int64
#  10  Final_Exam_Score            10 non-null     int64
#  11  Pass_Fail                   10 non-null     str
# dtypes: int64(6), str(6)
# memory usage: 1.1 KB

# %%
df.describe()
# Out:
#              Age  Study_Hours_Per_Week  Attendance_Percentage  Previous_Score  \
# count  10.000000             10.000000              10.000000       10.000000
# mean   17.000000             12.500000              83.000000       70.100000
# std     0.816497              4.949747              10.677078       11.189777
# min    16.000000              5.000000              65.000000       55.000000
# 25%    16.250000              8.500000              74.000000       61.250000
# 50%    17.000000             13.000000              86.500000       69.000000
# 75%    17.750000             15.750000              91.500000       77.000000
# max    18.000000             20.000000              95.000000       88.000000
#
#        Sleep_Hours  Final_Exam_Score
# count    10.000000          10.00000
# mean      6.800000          71.80000
# std       1.032796          14.46682
# min       5.000000          49.00000
# 25%       6.000000          60.25000
# 50%       7.000000          74.00000
# ...

# %%
df["Age"].mean()
# Out:
# np.float64(17.0)

# %%
df["Age"].median()
# Out:
# np.float64(17.0)

# %%
df["Age"].mode()
# Out:
# 0    17
# Name: Age, dtype: int64

# %%
df["Age"].var()
# Out:
# np.float64(0.6666666666666666)

# %%
df["Age"].std()
# Out:
# np.float64(0.816496580927726)

# %%
df["Age"].max()
# Out:
# np.int64(18)

# %%
df["Age"].min()
# Out:
# np.int64(16)

# %%
df["Age"].count()
# Out:
# np.int64(10)

# %%
df["Age"].unique()
# Out:
# array([17, 16, 18])

# %%
df["Age"].nunique()
# Out:
# 3

# %%
df["Age"].value_counts()
# Out:
# Age
# 17    4
# 16    3
# 18    3
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#    Student_ID  Gender    Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       False   False  False                 False                  False
# 1       False   False  False                 False                  False
# 2       False   False  False                 False                  False
# 3       False   False  False                 False                  False
# 4       False   False  False                 False                  False
# 5       False   False  False                 False                  False
# 6       False   False  False                 False                  False
# 7       False   False  False                 False                  False
# 8       False   False  False                 False                  False
# 9       False   False  False                 False                  False
#
#    Previous_Score  Parental_Education_Level  Internet_Access  \
# 0           False                     False            False
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Gender                        0
# Age                           0
# Study_Hours_Per_Week          0
# Attendance_Percentage         0
# Previous_Score                0
# Parental_Education_Level      0
# Internet_Access               0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Final_Exam_Score              0
# Pass_Fail                     0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Student_ID                    0.0
# Gender                        0.0
# Age                           0.0
# Study_Hours_Per_Week          0.0
# Attendance_Percentage         0.0
# Previous_Score                0.0
# Parental_Education_Level      0.0
# Internet_Access               0.0
# Extracurricular_Activities    0.0
# Sleep_Hours                   0.0
# Final_Exam_Score              0.0
# Pass_Fail                     0.0
# dtype: float64

# %%
df.dropna()
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
# 5       S006  Female   18                    14                     88
# 6       S007    Male   17                    10                     80
# 7       S008  Female   16                    18                     93
# 8       S009    Male   18                     7                     72
# 9       S010  Female   17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# ...

# %%
df.fillna(0)
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
# 5       S006  Female   18                    14                     88
# 6       S007    Male   17                    10                     80
# 7       S008  Female   16                    18                     93
# 8       S009    Male   18                     7                     72
# 9       S010  Female   17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# ...

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\4NI25CI004'

# %%
df.drop_duplicates()
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
# 5       S006  Female   18                    14                     88
# 6       S007    Male   17                    10                     80
# 7       S008  Female   16                    18                     93
# 8       S009    Male   18                     7                     72
# 9       S010  Female   17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# ...

# %%
df["Gender"]
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3    Female
# 4      Male
# 5    Female
# 6      Male
# 7    Female
# 8      Male
# 9    Female
# Name: Gender, dtype: str

# %%
df[["Gender","Age"]]
# Out:
#    Gender  Age
# 0    Male   17
# 1  Female   16
# 2    Male   18
# 3  Female   17
# 4    Male   16
# 5  Female   18
# 6    Male   17
# 7  Female   16
# 8    Male   18
# 9  Female   17

# %%
df.iloc[0:5]
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# 2              60              High School              No
# 3              88                   Master             Yes
# 4              55              High School              No
#
#   Extracurricular_Activities  Sleep_Hours  Final_Exam_Score Pass_Fail
# 0                        Yes            7                72      Pass
# ...

# %%
df[df["Age"]>17]
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 2       S003    Male   18                     8                     70
# 5       S006  Female   18                    14                     88
# 8       S009    Male   18                     7                     72
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 2              60              High School              No
# 5              70                 Bachelor             Yes
# 8              58              High School              No
#
#   Extracurricular_Activities  Sleep_Hours  Final_Exam_Score Pass_Fail
# 2                        Yes            6                58      Fail
# 5                        Yes            7                76      Pass
# 8                        Yes            6                54      Fail

# %%
df.sort_values("Age")
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 1       S002  Female   16                    15                     92
# 4       S005    Male   16                     5                     65
# 7       S008  Female   16                    18                     93
# 0       S001    Male   17                    12                     85
# 6       S007    Male   17                    10                     80
# 3       S004  Female   17                    20                     95
# 9       S010  Female   17                    16                     90
# 2       S003    Male   18                     8                     70
# 5       S006  Female   18                    14                     88
# 8       S009    Male   18                     7                     72
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 1              74                   Master             Yes
# 4              55              High School              No
# ...

# %%
df.rename(columns={"Age":"Age_Years"})
# Out:
#   Student_ID  Gender  Age_Years  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male         17                    12                     85
# 1       S002  Female         16                    15                     92
# 2       S003    Male         18                     8                     70
# 3       S004  Female         17                    20                     95
# 4       S005    Male         16                     5                     65
# 5       S006  Female         18                    14                     88
# 6       S007    Male         17                    10                     80
# 7       S008  Female         16                    18                     93
# 8       S009    Male         18                     7                     72
# 9       S010  Female         17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# ...

# %%
df["New_Score"]=df["Previous_Score"]+10

# %%
df.drop("New_Score",axis=1)
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
# 5       S006  Female   18                    14                     88
# 6       S007    Male   17                    10                     80
# 7       S008  Female   16                    18                     93
# 8       S009    Male   18                     7                     72
# 9       S010  Female   17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# ...

# %%
df.drop(["Bonus", "CGPA"], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# 2              60              High School              No
# 3              88                   Master             Yes
# 4              55              High School              No
#
#   Extracurricular_Activities  Sleep_Hours  Final_Exam_Score Pass_Fail  \
# 0                        Yes            7                72      Pass
# ...

# %%
df.groupby("Internet_Access")

# %%
df.groupby("Internet_Access")["Age"].mean()
# Out:
# Internet_Access
# No     17.333333
# Yes    16.857143
# Name: Age, dtype: float64

# %%
df1=df.iloc[:5]
df2=df.iloc[5:]

# %%
df1.head()
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# 2              60              High School              No
# 3              88                   Master             Yes
# 4              55              High School              No
#
#   Extracurricular_Activities  Sleep_Hours  Final_Exam_Score Pass_Fail  \
# 0                        Yes            7                72      Pass
# ...

# %%
df2.head()
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 5       S006  Female   18                    14                     88
# 6       S007    Male   17                    10                     80
# 7       S008  Female   16                    18                     93
# 8       S009    Male   18                     7                     72
# 9       S010  Female   17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 5              70                 Bachelor             Yes
# 6              65                 Bachelor             Yes
# 7              85                   Master             Yes
# 8              58              High School              No
# 9              78                 Bachelor             Yes
#
#   Extracurricular_Activities  Sleep_Hours  Final_Exam_Score Pass_Fail  \
# 5                        Yes            7                76      Pass
# ...

# %%
pd.concat([df1,df2])
# Out:
#   Student_ID  Gender  Age  Study_Hours_Per_Week  Attendance_Percentage  \
# 0       S001    Male   17                    12                     85
# 1       S002  Female   16                    15                     92
# 2       S003    Male   18                     8                     70
# 3       S004  Female   17                    20                     95
# 4       S005    Male   16                     5                     65
# 5       S006  Female   18                    14                     88
# 6       S007    Male   17                    10                     80
# 7       S008  Female   16                    18                     93
# 8       S009    Male   18                     7                     72
# 9       S010  Female   17                    16                     90
#
#    Previous_Score Parental_Education_Level Internet_Access  \
# 0              68                 Bachelor             Yes
# 1              74                   Master             Yes
# ...
